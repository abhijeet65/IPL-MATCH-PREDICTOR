# %%
import pandas as pd
import numpy as np
df={"HardHitter":[],"FastScorer":[],"Bat_Average":[],"Economy":[],"WicketTaker":[],"Bowl_Average":[]}
pd.DataFrame(df).to_csv("Player_Rating.csv")
bat_df=pd.read_csv('batsmen_stats.csv')
bowl_df=pd.read_csv("bowlers_stats.csv")
bat_list=[]
for ind in bat_df.index:
    bat_list.append(bat_df.iloc[ind][0])
    #print(ind)
    hard_hitter=(((bat_df["4"][ind]*4)+(bat_df["6"][ind]*6))/max(bat_df["Balls"][ind],1))
    df['HardHitter'].append(hard_hitter)
    fast_scorer=((bat_df["Runs"][ind])/max(bat_df["Balls"][ind],1))
    df["FastScorer"].append(fast_scorer)
    bat_average=(bat_df["Runs"][ind]/max(1,bat_df["Dismissals"][ind]))
    df["Bat_Average"].append( bat_average)
    df["Economy"].append(0)
    df["WicketTaker"].append(0)
    df["Bowl_Average"].append(0)
df=pd.DataFrame(df,index=bat_list)
#print(df)
for i in df:
    df[i]=df[i].astype(float)
for ind in bowl_df.index:
    if bowl_df.iloc[ind][0] in bat_list:
        economy=((bowl_df["Runs"][ind])*6.00)/(max(1,bowl_df["Balls"][ind]))
        df["Economy"][bowl_df.iloc[ind][0]]=economy
        wicket_taker=(bowl_df["Balls"][ind]/max(1,bowl_df["Wickets"][ind]))
        df["WicketTaker"][bowl_df.iloc[ind][0]]=wicket_taker
        bowl_average=(bowl_df["Runs"][ind])/(max(1,bowl_df["Wickets"][ind]))
        df["Bowl_Average"][bowl_df.iloc[ind][0]]=bowl_average
    else:
        economy=((bowl_df["Runs"][ind])*6.00)/(max(1,bowl_df["Balls"][ind]))
        wicket_taker=(bowl_df["Balls"][ind]/max(1,bowl_df["Wickets"][ind]))
        bowl_average=(bowl_df["Runs"][ind])/(max(1,bowl_df["Wickets"][ind]))
        df2={"HardHitter":[0],"FastScorer":[0],"Bat_Average":[0],"Economy":[economy],"WicketTaker":[wicket_taker],"Bowl_Average":[bowl_average]}
        df2=pd.DataFrame(df2,index=[bowl_df.iloc[ind][0]])
        df=pd.concat([df,df2])
        
print(df)
# Out:
#                    HardHitter  FastScorer  Bat_Average    Economy  \
# A Ashish Reddy       0.785714    1.428571    21.538462   8.613636
# NLTC Perera          0.760736    1.300613    20.190476   8.504348
# SK Trivedi           0.295082    0.688525     6.000000   7.090559
# GB Hogg              0.181818    1.000000    11.000000   7.107296
# SM Pollock           0.827586    1.267241    18.375000   6.364286
# Sunny Gupta          0.000000    0.000000     0.000000  14.210526
# DR Smith             0.932890    1.322795    30.189873   8.477558
# DJ Thornely          0.370370    0.722222    13.000000   5.181818
# GS Sandhu            0.000000    0.000000     0.000000  10.250000
# Tejas Baroka         0.000000    0.000000     0.000000   9.428571
# Harmeet Singh (2)    0.000000    0.000000     0.000000   7.920000
# B Stanlake           0.000000    0.000000     0.000000   8.160000
# MG Neser             0.000000    0.000000     0.000000  14.640000
# MB Parmar            0.000000    0.000000     0.000000  10.105263
#
#                    WicketTaker  Bowl_Average
# A Ashish Reddy       15.529412     22.294118
# NLTC Perera          23.000000     32.600000
# SK Trivedi           23.953846     28.307692
# GB Hogg              20.260870     24.000000
# SM Pollock           25.454545     27.000000
# Sunny Gupta          19.000000     45.000000
# DR Smith             21.423077     30.269231
# DJ Thornely          14.666667     12.666667
# DT Patil              0.000000      0.000000
# WA Mota              18.750000     23.500000
# I Malhotra            6.000000     23.000000
# J Yadav              45.750000     48.250000
# M Ntini              30.428571     34.000000
# GH Vihari            31.000000     32.000000
# NL McCullum          30.000000     34.000000
# MD Mishra             0.000000      0.000000
# JEC Franklin         17.222222     24.000000
# Pankaj Singh         28.272727     41.181818
# R Tewatia            21.333333     22.833333
# A Flintoff           33.000000     52.500000
# AL Menaria           37.666667     46.666667
# Gurkeerat Singh      16.400000     18.600000
# M Muralitharan       25.524590     26.655738
# R Bishnoi             0.000000      0.000000
# P Sahu               35.666667     48.000000
# Karanveer Singh      17.750000     26.000000
# BR Dunk               0.000000      0.000000
# S Ladda              28.200000     44.200000
# DJG Sammy            22.181818     31.000000
# SV Samson             0.000000      0.000000
# ...                        ...           ...
# SS Sarkar            25.000000     34.000000
# JW Hastings          20.333333     21.000000
# P Prasanth            6.000000     18.000000
# Mustafizur Rahman    23.117647     26.117647
# Mohammed Siraj       14.100000     20.900000
# TP Sudhindra         74.000000    132.000000
# AA Kazi              13.000000     20.000000
# T Natarajan          41.000000     54.500000
# P Amarnath           18.857143     33.714286
# T Shamsi             32.000000     49.000000
# AM Salvi             22.285714     27.142857
# B Geeves             49.000000     90.000000
# K Santokie           17.000000     29.000000
# SS Agarwal           24.000000     42.000000
# NB Singh             25.000000     14.000000
# MJ Henry             31.000000     70.000000
# SM Boland            21.500000     26.500000
# RA Shaikh             6.000000     11.000000
# P Suyal              53.500000     70.000000
# Anand Rajan          20.250000     23.500000
# Avesh Khan           24.000000     23.000000
# A Nel                18.000000     31.000000
# RW Price             18.000000     33.000000
# RR Bose              12.000000     24.000000
# GS Sandhu            48.000000     82.000000
# Tejas Baroka         21.000000     33.000000
# Harmeet Singh (2)    25.000000     33.000000
# B Stanlake           25.000000     34.000000
# MG Neser             25.000000     61.000000
# MB Parmar            19.000000     32.000000
#
# [494 rows x 6 columns]
